# %% [markdown]
# <a href="https://colab.research.google.com/github/Varshithatangeti/FMML_2023_ASSIGNMENTS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-27 16:40:05--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   176MB/s    in 0.4s
#
# 2024-03-27 16:40:06 (176 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 27397  1703.05455v2  In this paper, we propose a ranking based loca...    cs
# 27809  1704.06040v1  The ability to automatically learn task specif...    cs
# 27334  1703.03329v2  Current action recognition methods heavily rel...    cs
# 23160   0805.3964v2  Feature selection is a pattern recognition app...    cs
# 1628   1701.06247v1  The fifth Dialog State Tracking Challenge (DST...    cs
# ...             ...                                                ...   ...
# 21936  1612.00595v2  We introduce a novel approach for parallelizin...  stat
# 34617  1706.07859v1  End-to-end learning treats the entire system a...    cs
# 15074   1401.6122v1  One of the key issues in both natural language...    cs
# 3983    0904.4587v1  A efficient incremental learning algorithm for...    cs
# 20933  1705.06342v1  In this work, we present a methodology that en...    cs
#
#                                                    title  year  \
# 27397  Ranking Based Locality Sensitive Hashing Enabl...  2017
# 27809  Understanding the Mechanisms of Deep Transfer ...  2017
# 27334  UntrimmedNets for Weakly Supervised Action Rec...  2017
# 23160  DimReduction - Interactive Graphic Environment...  2008
# 1628   A Multichannel Convolutional Neural Network Fo...  2017
# ...                                                  ...   ...
# 21936  Parallel Chromatic MCMC with Spatial Partitioning  2016
# 34617  Deep Speaker Verification: Do We Need End to End?  2017
# 15074  Identifying Bengali Multiword Expressions usin...  2014
# 3983               Adaptive Learning with Binary Neurons  2009
# 20933  Identification and Off-Policy Learning of Mult...  2017
#
#                                                 keywords
# 27397  [sensitive, cancelable, biometrics, biometric,...
# 27809  [automatically, representations, effective, sy...
# 27334  [recognition, expensive, consuming, supervised...
# 23160  [selection, recognition, important, variables,...
# 1628   [challenge, introduces, participants, evaluati...
# ...                                                  ...
# 21936  [introduce, parallelizing, inference, spatiall...
# 34617  [adaptable, sufficient, available, principle, ...
# 15074  [understanding, generation, appropriate, proce...
# 3983   [efficient, incremental, algorithm, classifica...
# 20933  [methodology, efficient, exploratory, autonomo...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 27397    [sensitive, cancelable, biometrics, biometric,...
# 27809    [automatically, representations, effective, sy...
# 27334    [recognition, expensive, consuming, supervised...
# 23160    [selection, recognition, important, variables,...
# 1628     [challenge, introduces, participants, evaluati...
#                                ...
# 29442    [recognition, development, recognition, especi...
# 22957    [classifiers, available, examining, diversity,...
# 2095     [challenge, generalize, different, optimizatio...
# 22814    [processes, uncertainty, functions, advantages...
# 4411     [assistance, significantly, effective, predict...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8750 words.
# Out of those 4529 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d9a7eca3-3507-41df-a3b1-71aa729450af" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d9a7eca3-3507-41df-a3b1-71aa729450af")) {                    Plotly.newPlot(                        "d9a7eca3-3507-41df-a3b1-71aa729450af",                        [{"x":["benchmark","uniformly","protection","experimental","permutation","representation","parameters","invariant","insensitive","resilience","favorable","contributes","independence","cancelable","guarantee","projection","externally","transforms","biometric","generated","variation","information","introduced","fingerprint","sensitive","realizations","invertibility","performance","alignment","databases","magnitude","biometrics","demonstrate","convolutional","systematically","transferring","processing","understanding","classification","transferred","effectively","evolution","responses","ultrasound","effective","mechanisms","automatically","techniques","investigate","outperform","intermediate","engineered","hybridization","detection","representations","consuming","trainable","therefore","expensive","comparable","requirement","instances","components","implemented","important","supervision","recognition","supervised","respectively","architecture","annotations","approaches","untrimmed","selection","proteomic","biological","functions","distinguish","applications","bioinformatics","difficult","selecting","variables","prediction","probabilities","phenomena","questions","according","environment","algorithms","interactive","informative","dimensionality","inference","reduction","graphical","signature","criterion","recurrent","participants","challenge","knowledge","introduces","translation","unlabeled","robustness","translations","multichannel","additionally","developer","evaluation","languages","desirable","evaluating","different","generalization","significantly","inspiring","combining","identification","strategies","comparing","constraint","presented","euclidean","benchmarks","challenging","illumination","embedding","manifolds","especially","distribution","capability","distributed","approximating","relationship","experiments","occlusion","variations","extraction","pedestrian","accordingly","outperforms","regularization","coherence","available","complexity","collected","coefficient","specificity","automated","conservative","assessment","diminishing","intraoperative","simulates","evaluated","sensitivity","correlation","tomography","computationally","comparison","literature","approximately","objective","significance","conclusion","competing","demonstrated","configurations","application","overfitting","factorization","uncertainty","exploring","posterior","principled","nonparametric","extension","variational","unfortunately","asymptotically","synthetic","framework","characterize","introduce","exploration","classifiers","insufficient","differently","perturbation","architectures","vulnerable","virtually","perturbations","compression","adversarial","classifier","represent","increases"],"y":[170,12,5,384,13,395,279,76,6,8,11,14,35,2,32,55,4,24,15,155,57,649,126,9,59,2,1,891,45,49,53,12,537,367,32,15,290,161,489,14,121,67,35,6,264,44,168,379,156,96,28,16,4,345,233,46,13,148,76,102,22,95,101,88,350,37,353,182,87,265,52,444,2,184,2,45,210,30,439,11,132,49,146,235,48,37,64,101,121,590,30,33,53,226,100,58,12,52,150,15,137,347,62,125,46,80,22,4,65,2,265,110,35,55,761,122,257,3,99,115,85,70,87,191,33,96,262,42,112,17,110,214,64,112,23,83,574,25,59,145,20,13,285,82,15,292,216,63,20,9,96,2,42,0,1,5,114,35,63,11,110,114,132,36,173,15,20,40,97,29,239,28,45,80,42,40,29,22,72,55,33,8,150,526,41,327,38,99,12,15,16,131,16,4,21,52,88,120,141,54],"type":"bar"},{"x":["benchmark","uniformly","protection","experime ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4529,), (4529, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.805

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Constrained</span> <span style=''>Image</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>Generation</span> <span style=''>Using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Binarized</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>with</span> <span style=''>Decision</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Procedures</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>binary</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>generation</span> <span style=''>with</span> <span style=''>given</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>This</span> <span style=''>problem</span> <span style=''>arises</span> <span style=''>in</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>including</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>generation</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.4725274725274725);'>artificial</span> <span style=''>porous</span> <span style=''>medium</span> <span style=''>for</span> <span style=''>an</span> <span style=''>electrode</span> <span style=''>of</span> <span style=''>lithium</span> <span style=''>ion</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>batteries</span> <span style=''>for</span> <span style=''>composed</span> <span style='background-color:rgba(0, 255, 0, 0.8571428571428572);'>materials</span> <span style=''>etc</span> <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generated</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>represents</span> <span style=''>a</span> <span style=''>porous</span> <span style=''>medium</span> <span style=''>and</span> <span style=''>as</span> <span style=''>such</span> <span style=''>it</span> <span style=''>is</span> <span style=''>subject</span> <span style=''>to</span> <span style=''>two</span> <span style=''>sets</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style='background-color:rgba(0, 255, 0, 0.4210526315789474);'>topological</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>and</span> <span style=''>process</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style=''>on</span> <span style=''>the</span> <span style=''>physical</span> <span style=''>process</span> <span style=''>over</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>To</span> <span style=''>perform</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>generation</span> <span style=''>we</span> <span style=''>need</span> <span style=''>to</span> <span style=''>define</span> <span style=''>a</span> <span style=''>mapping</span> <span style=''>from</span> <span style=''>a</span> <span style=''>porous</span> <span style=''>medium</span> <span style=''>to</span> <span style=''>its</span> <span style=''>physical</span> <span style=''>process</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>For</span> <span style=''>a</span> <span style=''>given</span> <span style=''>geometry</span> <span style=''>of</span> <span style=''>a</span> <span style=''>porous ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Generalization</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Robustness</span> <span style=''>of</span> <span style=''>Batched</span> <span style=''>Weighted</span> <span style=''>Average</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Algorithm</span> <span style=''>with</span> <span style=''>V</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>geometrically</span> <span style=''>Ergodic</span> <span style=''>Markov</span> <span style=''>Data</span> <br/><br/><span style=''>We</span> <span style=''>analyze</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>robustness</span> <span style=''>of</span> <span style=''>the</span> <span style=''>batched</span> <span style=''>weighted</span> <span style=''>average</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>V</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>geometrically</span> <span style=''>ergodic</span> <span style=''>Markov</span> <span style=''>data</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>a</span> <span style=''>good</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternative</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style=''>risk</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>when</span> <span style=''>the</span> <span style=''>latter</span> <span style=''>suffers</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>overfitting</span> <span style=''>or</span> <span style=''>when</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimizing</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style=''>risk</span> <span style=''>is</span> <span style=''>hard</span> <span style=''>For</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>we</span> <span style=''>prove</span> <span style=''>a</span> <span style=''>PAC</span> <span style=''>style</span> <span style=''>bound</span> <span style=''>on</span> <span style=''>the</span> <span style=''>training</span> <span style=''>sample</span> <span style=''>size</span> <span style=''>for</span> <span style=''>the</span> <span style=''>expected</span> <span style=''>L</span> <span style=''>1</span> <span style=''>loss</span> <span style=''>to</span> <span style=''>converge</span> <span style=''>to</span> <span style=''>the</span> <span style=''>optimal</span> <span style=''>loss</span> <span style=''>when</span> <span style=''>training</span> <span style=''>data</span> <span style=''>are</span> <span style=''>V</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>geometrically</span> <span style=''>ergodic</span> <span style=''>Markov</span> <span style=''>chains</span> <span style=''>For</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>robustness</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>if</span> <span style=''>the</span> <span style=''>training</span> <span style=''>target</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>values</span> <span style=''>contain</span> <span style=''>bounded</span> <span style=''>noise</span> <span style=''>then</span> <span styl ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Near</span> <span style=''>optimal</span> <span style=''>sample</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>for</span> <span style=''>convex</span> <span style=''>tensor</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>completion</span> <br/><br/><span style=''>We</span> <span style=''>analyze</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>tensor</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>completion</span> <span style=''>(TC)</span> <span style=''>using</span> <span style=''>noisy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>measurements</span> <span style=''>of</span> <span style=''>a</span> <span style=''>subset</span> <span style=''>of</span> <span style=''>the</span> <span style=''>tensor</span> <span style=''>Assuming</span> <span style=''>a</span> <span style=''>rank</span> <span style=''>r</span> <span style=''>order</span> <span style=''>d</span> <span style=''>N</span> <span style=''>times</span> <span style=''>N</span> <span style=''>times</span> <span style=''>cdots</span> <span style=''>times</span> <span style=''>N</span> <span style=''>tensor</span> <span style=''>where</span> <span style=''>rO(1)</span> <span style=''>the</span> <span style=''>best</span> <span style=''>sampling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>that</span> <span style=''>was</span> <span style=''>achieved</span> <span style=''>is</span> <span style=''>O(Nfracd2)</span> <span style=''>which</span> <span style=''>is</span> <span style=''>obtained</span> <span style=''>by</span> <span style=''>solving</span> <span style=''>a</span> <span style=''>tensor</span> <span style=''>nuclear</span> <span style=''>norm</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>problem</span> <span style=''>However</span> <span style=''>this</span> <span style=''>bound</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>significantly</span> <span style=''>larger</span> <span style=''>than</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>free</span> <span style='background-color:rgba(255, 0, 0, 0.30805687203791465);'>variables</span> <span style=''>in</span> <span style=''>a</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>tensor</span> <span style=''>which</span> <span style=''>is</span> <span style=''>O(dN)</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>by</span> <span style=''>using</span> <span style=''>an</span> <span style=''>atomic</span> <span style=''>norm</span> <span style=''>whose</span> <span style=''>atoms</span> <span style=''>are</span> <span style=''>rank</span> <span style=''>1</span> <span style=''>sign</span> <span style=''>tensors</span> <span style=''>one</span> <span style=''>can</span> <span style=''>obtain</span> <span style=''>a</span> <span style=''>sample</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>of</span> <span style=''>O(dN)</span> <span style=''>Moreover</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalize</span> <span style=''>the</span> <span style=''>matrix</span> <span style=''>max</span> <span style=''>norm</span> <span style='background-color:rgba(0, 255, 0, 0.36231884057971014);'>definition</span> <span style=''>to</span> <span style=''>tensors</span> <span style=''>which</span> <span style=''>results</span> <span style=''>in</span> <span style=''>a</span> <span style=''>max</span> <span style=''>quasi</span> <span style=''>norm</span> <span style=''>(max</span> <span style=''>qnorm)</span> <span style=''>whose</span> <span style=''>unit</span> <span style=''>bal ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Extrapolating</span> <span style=''>Expected</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Accuracies</span> <span style=''>for</span> <span style=''>Large</span> <span style=''>Multi</span> <span style=''>Class</span> <span style=''>Problems</span> <br/><br/><span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficulty</span> <span style=''>of</span> <span style=''>multi</span> <span style=''>class</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increases</span> <span style=''>with</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>classes</span> <span style=''>Using</span> <span style=''>data</span> <span style=''>from</span> <span style=''>a</span> <span style=''>subset</span> <span style=''>of</span> <span style=''>the</span> <span style=''>classes</span> <span style=''>can</span> <span style=''>we</span> <span style=''>predict</span> <span style=''>how</span> <span style=''>well</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>will</span> <span style=''>scale</span> <span style=''>with</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increased</span> <span style=''>number</span> <span style=''>of</span> <span style=''>classes</span> <span style=''>Under</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style=''>that</span> <span style=''>the</span> <span style=''>classes</span> <span style=''>are</span> <span style=''>sampled</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identically</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independently</span> <span style=''>from</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>population</span> <span style=''>and</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independently</span> <span style=''>learned</span> <span style=''>scoring</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>expected</span> <span style=''>accuracy</span> <span style=''>when</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>is</span> <span style=''>trained</span> <span style=''>on</span> <span style=''>k</span> <span style=''>classes</span> <span style=''>is</span> <span style=''>the</span> <span style=''>(k</span> <span style=''>1)st</span> <span style=''>moment</span> <span style=''>of</span> <span style=''>a</span> <span style=''>certain</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimated</span> <span style=''>from</span> <span style=''>data</span> <span style=''>We</span> <span style=''>present</span> <span style=''>an</span> <span style=''>unbiased</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>method</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>theory</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>application</span> <span style=''>on</s ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10334996436208126)
# 	information (0.23129009265858874)
# 	experimental (0.1368496079828938)
# 	representation (0.1407697790449038)
# 	segmentation (0.07305773342836779)
# 	architecture (0.09444048467569494)
# 	detection (0.12295081967213115)
# 	recognition (0.12580185317177478)
# 	different (0.2712045616535994)
# 	convolutional (0.1307911617961511)
#
# Some Statistics words are:
# 	variables (0.13841524573721165)
# 	estimation (0.17251755265797392)
# 	stochastic (0.137913741223671)
# 	theoretical (0.15095285857572718)
# 	statistical (0.15997993981945838)
# 	distribution (0.18204613841524575)
# 	algorithm (0.3881644934804413)
# 	inference (0.2001003009027081)
# 	dimensional (0.19157472417251756)
# 	regression (0.17352056168505517)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b3048ea1-7045-4a04-b691-54d81df68877" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b3048ea1-7045-4a04-b691-54d81df68877")) {                    Plotly.newPlot(                        "b3048ea1-7045-4a04-b691-54d81df68877",                        [{"x":["benchmark","uniformly","protection","experimental","permutation","representation","parameters","invariant","insensitive","resilience","favorable","contributes","independence","cancelable","guarantee","projection","externally","transforms","biometric","generated","variation","information","introduced","fingerprint","sensitive","realizations","invertibility","performance","alignment","databases","magnitude","biometrics","demonstrate","convolutional","systematically","transferring","processing","understanding","classification","transferred","effectively","evolution","responses","ultrasound","effective","mechanisms","automatically","techniques","investigate","outperform","intermediate","engineered","hybridization","detection","representations","consuming","trainable","therefore","expensive","comparable","requirement","instances","components","implemented","important","supervision","recognition","supervised","respectively","architecture","annotations","approaches","untrimmed","selection","proteomic","biological","functions","distinguish","applications","bioinformatics","difficult","selecting","variables","prediction","probabilities","phenomena","questions","according","environment","algorithms","interactive","informative","dimensionality","inference","reduction","graphical","signature","criterion","recurrent","participants","challenge","knowledge","introduces","translation","unlabeled","robustness","translations","multichannel","additionally","developer","evaluation","languages","desirable","evaluating","different","generalization","significantly","inspiring","combining","identification","strategies","comparing","constraint","presented","euclidean","benchmarks","challenging","illumination","embedding","manifolds","especially","distribution","capability","distributed","approximating","relationship","experiments","occlusion","variations","extraction","pedestrian","accordingly","outperforms","regularization","coherence","available","complexity","collected","coefficient","specificity","automated","conservative","assessment","diminishing","intraoperative","simulates","evaluated","sensitivity","correlation","tomography","computationally","comparison","literature","approximately","objective","significance","conclusion","competing","demonstrated","configurations","application","overfitting","factorization","uncertainty","exploring","posterior","principled","nonparametric","extension","variational","unfortunately","asymptotically","synthetic","framework","characterize","introduce","exploration","classifiers","insufficient","differently","perturbation","architectures","vulnerable","virtually","perturbations","compression","adversarial","classifier","represent","increases","potential","imperceptible","specifically","counterexample","counterexamples","successfully","technique","autonomous","particular","iteratively","algorithm","optimization","satisfiability","inductive","dimensional","characteristic","separation","observation","recursive","effectiveness","statistical","thresholds","distributions","furthermore","mahalanobis","incorporates","typically","represented","segregation","procedure","localized","threshold","corresponding","negligible","consequences","appropriate","essential","computation","analyzing","feasibility","direction","degradation","computational","theoretical","essentially","additional","developed","connections","theoretically","expectation","activation","concerning" ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	diminishing
# 	unattainable
# 	nucleotide
# 	curvatures
# 	resiliency
# 	deletions
# 	adaptiveness
# 	generalisations
# 	embarrassingly
# 	geosciences
# 	underpowered
# 	exemplify
# 	bernstein
# 	penalization
# 	couplings
# 	cumulants
# 	normalised
# 	epigenomics
# 	hoeffding
# 	minimiser
# Some words which never appear in Statistics papers:
# 	cancelable
# 	biometric
# 	biometrics
# 	ultrasound
# 	untrimmed
# 	proteomic
# 	developer
# 	inspiring
# 	illumination
# 	pedestrian
# 	segregation
# 	replicating
# 	antibiotics
# 	communicative
# 	instruction
# 	combinatory
# 	categorial
# 	superpixel
# 	constancy
# 	deductive

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.068520052778545e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7558333333333334
